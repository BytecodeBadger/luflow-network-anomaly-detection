# %% [markdown]
# # LuFlow Network Anomaly Detection
#
# This notebook uses the Lancaster University network flow dataset to perform exploration and anomaly detection.

# %% [markdown]
# import pandas
# import numpy
# import matplotlib
# import seaborn
